# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carrega amostra local para exploracao inicial
df = pd.read_csv('/Users/gustavosoares/Documents/Pos Tech/tech_challeng/tech_challeng_2/data/raw/inep/br_inep_avaliacao_alfabetizacao_meta_alfabetizacao_uf.csv')
df.head()
# Out:
#     ano sigla_uf     rede  taxa_alfabetizacao  meta_alfabetizacao_2024  \
# 0  2024       RR  Pública                 NaN                      NaN
# 1  2023       RR  Pública                 NaN                      NaN
# 2  2023       AC  Pública                 NaN                      NaN
# 3  2024       AC  Pública               51.38                      NaN
# 4  2023       DF  Pública                 NaN                      NaN
#
#    meta_alfabetizacao_2025  meta_alfabetizacao_2026  meta_alfabetizacao_2027  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                     56.9                     62.2                     67.3
# 3                     56.9                     62.2                     67.3
# 4                     63.1                     67.0                     70.6
#
# ...

# %%
nulos = pd.DataFrame({
    "nulos": df.isna().sum(),
    "total": len(df),
    "pct_nulos": (df.isna().mean() * 100).round(2)
}).sort_values("pct_nulos", ascending=False)

nulos
# Out:
#                          nulos  total  pct_nulos
# meta_alfabetizacao_2024      6     54      11.11
# taxa_alfabetizacao           4     54       7.41
# percentual_participacao      4     54       7.41
# meta_alfabetizacao_2025      2     54       3.70
# meta_alfabetizacao_2026      2     54       3.70
# meta_alfabetizacao_2027      2     54       3.70
# meta_alfabetizacao_2028      2     54       3.70
# meta_alfabetizacao_2029      2     54       3.70
# meta_alfabetizacao_2030      2     54       3.70
# ano                          0     54       0.00
# sigla_uf                     0     54       0.00
# rede                         0     54       0.00

# %%
print(df.nunique())
# Out:
# ano                         2
# sigla_uf                   27
# rede                        1
# taxa_alfabetizacao         50
# meta_alfabetizacao_2024    24
# meta_alfabetizacao_2025    26
# meta_alfabetizacao_2026    24
# meta_alfabetizacao_2027    24
# meta_alfabetizacao_2028    23
# meta_alfabetizacao_2029    21
# meta_alfabetizacao_2030     1
# percentual_participacao    49
# dtype: int64
